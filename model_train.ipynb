# %%
import numpy as np
import pandas as pd

from NeuralNetwork import NeuralNetwork

# %%
df = pd.read_csv("tictactoe_moves.csv")
df.head()

# %%
def train_test_split(X, y, test_size=0.2, random_state=None):

    if random_state is not None:
        np.random.seed(random_state)

    indices = np.random.permutation(len(X))

    split = int(len(X) * (1 - test_size))

    train_indices = indices[:split]
    test_indices = indices[split:]

    X_train = X.iloc[train_indices]
    X_test = X.iloc[test_indices]

    y_train = y.iloc[train_indices]
    y_test = y.iloc[test_indices]

    return X_train, X_test, y_train, y_test

# %%
def accuracy_score(y_true, y_pred):
    return np.mean(y_true == y_pred)

# %%
X = df.copy()
X.drop(columns= ["best_move","best_moves_all"],inplace=True)
y = df["best_move"].copy()

# %%
X_train, X_test,y_train,y_test = train_test_split(X,y,random_state=42,test_size=0.25)

# %%
nn = NeuralNetwork(hidden_layers=1, lr=0.5, layer_neurons=128, n_iters=2000)
nn.fit(X_train,y_train,multi=True)

# %%
preds = nn.predict(X_test)
print(f"score: {accuracy_score(y_test,preds)}")

# %%
nn = NeuralNetwork(hidden_layers=1, lr=0.5, layer_neurons=128, n_iters=2000)
nn.fit(X,y,multi=True)

# %%
nn.save("models/easy.npz")
